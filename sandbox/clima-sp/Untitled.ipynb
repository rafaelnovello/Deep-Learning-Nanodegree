# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('/home/rafael/Área de Trabalho/clima-sp-dataset.csv', sep=';')

# %%
df.head()
# Out:
#    Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 0    83781  01/01/1961     0           NaN        24.9         NaN
# 1    83781  01/01/1961  1200           0.0         NaN        18.5
# 2    83781  02/01/1961     0           NaN        22.7         NaN
# 3    83781  02/01/1961  1200           5.0         NaN        19.7
# 4    83781  03/01/1961     0           NaN        28.5         NaN
#
#    Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media  \
# 0            21.22                    89.0                   5.000000
# 1              NaN                     NaN                        NaN
# 2            20.84                    96.5                   3.366667
# 3              NaN                     NaN                        NaN
# 4            21.70                    79.0                   3.100000
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail()
# Out:
#        Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 40532    83781  27/05/2017  1200           0.0         NaN        18.3
# 40533    83781  28/05/2017     0           NaN        21.8         NaN
# 40534    83781  28/05/2017  1200           0.0         NaN        18.3
# 40535    83781  29/05/2017     0           NaN        25.2         NaN
# 40536    83781  29/05/2017  1200           0.0         NaN        14.9
#
#        Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media  \
# 40532              NaN                     NaN                        NaN
# 40533            19.34                   88.00                    1.54332
# 40534              NaN                     NaN                        NaN
# 40535            19.72                   74.25                    1.71480
# 40536              NaN                     NaN                        NaN
#
#        Unnamed: 9
# 40532         NaN
# 40533         NaN
# 40534         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40537 entries, 0 to 40536
# Data columns (total 10 columns):
# Estacao                      40537 non-null int64
# Data                         40537 non-null object
# Hora                         40537 non-null int64
# Precipitacao                 20300 non-null float64
# TempMaxima                   19985 non-null float64
# TempMinima                   20044 non-null float64
# Temp Comp Media              19943 non-null float64
# Umidade Relativa Media       20161 non-null float64
# Velocidade do Vento Media    20234 non-null float64
# Unnamed: 9                   0 non-null float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#        Estacao          Hora  Precipitacao    TempMaxima    TempMinima  \
# count  40537.0  40537.000000  20300.000000  19985.000000  20044.000000
# mean   83781.0    600.932481      4.259931     25.442702     15.863770
# std        0.0    600.006676     10.747924      4.355825      3.365318
# min    83781.0      0.000000      0.000000      8.500000      0.800000
# 25%    83781.0      0.000000      0.000000     22.500000     13.600000
# 50%    83781.0   1200.000000      0.000000     25.800000     16.100000
# 75%    83781.0   1200.000000      2.200000     28.700000     18.500000
# max    83781.0   1200.000000    151.800000     37.800000     25.400000
#
#        Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media  \
# count     19943.000000            20161.000000               20234.000000
# mean         19.752757               76.020175                   2.600472
# std           3.472067               11.153163                   1.174374
# ...

# %%
df[df.index > 35124][['Data', 'Precipitacao']].dropna().plot(x='Data', y='Precipitacao', figsize=(18,6))

# %%
import seaborn as sns
