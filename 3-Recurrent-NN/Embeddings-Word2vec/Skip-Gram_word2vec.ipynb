# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    window_size = np.random.choice(range(1, window_size+1))
    start = idx - window_size if (idx - window_size) > 0 else 0
    end = idx + window_size
    
    window = set(words[start:idx] + words[idx+1:end+1])
    return list(window)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='inputs')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w, softmax_b,
        labels, embed,
        n_sampled, n_vocab
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6846 0.2418 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6113 0.2141 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5104 0.2248 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5782 0.2525 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4938 0.2475 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5675 0.2486 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5540 0.2479 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5333 0.2478 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4820 0.2474 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4426 0.2472 sec/batch
# Nearest to up: villa, jansenist, shiv, lingvo, illusion, sidi, competing, cranberry,
# Nearest to is: qm, later, deductive, capital, ride, corporal, arabah, jfduke,
# Nearest to that: parliamentarian, maketh, screaming, varga, pompeius, originals, embracing, s,
# Nearest to most: balder, deville, scudo, ncos, grammys, abugidas, superb, resorts,
# Nearest to often: presupposes, potential, scribe, sincerity, cowper, manuscript, khmelnytsky, colder,
# Nearest to so: limited, manners, focusing, graf, buttons, adherent, vld, argento,
# Nearest to called: lonely, inception, wrapped, chapterhouse, reggie, telephoned, roger, phillippe,
# Nearest to also: deltas, armagh, haliaeetus, tans, differentiating, attractive, e, conger,
# Nearest to operating: multiplexing, conquer, valvular, minarchism, daylight, futility, unreactive, kite,
# Nearest to assembly: centrale, terrorists, sha, willard, specter, satisfy, shaanxi, scans,
# Nearest to test: fierce, crusade, inte, frankenheimer, kendrick, saarc, carmel, favorably,
# Nearest to scale: lugo, marty, prohibits, tristram, gysin, macedonian, page, cardiff,
# Nearest to cost: entrepreneurship, booming, presley, captains, circassians, prominently, varanasi, aurelia,
# Nearest to know: spoiled, digestion, markschies, elle, hoped, acct, drive, popping,
# Nearest to defense: xenophobic, imperial, litigation, sockets, mepkin, noonan, troposphere, forgetful,
# Nearest to primarily: summits, pumped, acknowledged, epimetheus, akad, roos, sufferer, inflexible,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4598 0.2531 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3620 0.2640 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3339 0.2291 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2350 0.2214 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1940 0.2161 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1397 0.2231 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0893 0.2488 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0416 0.2467 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9991 0.2492 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9757 0.2469 sec/batch
# Nearest to up: illusion, villa, competing, transport, this, pc, have, mexico,
# Nearest to is: later, capital, ride, qm, extant, deductive, everything, chair,
# Nearest to that: maketh, screaming, parliamentarian, embracing, replaced, varga, standard, book,
# Nearest to most: ncos, balder, figure, ab, resorts, deville, superb, grammys,
# Nearest to often: presupposes, potential, traditional, crossing, temperatures, scribe, diets, short,
# Nearest to so: limited, focusing, historic, manners, buttons, hospital, nicholas, graf,
# Nearest to called: lonely, inception, wrapped, importance, chapterhouse, social, roger, pioneers,
# Nearest to also: attractive, e, ground, armagh, deltas, deals, promote, tans,
# Nearest to operating: conquer, dutch, multiplexing, daylight, kite, doughnut, quoted, shown,
# Nearest to assembly: terrorists, centrale, satisfy, scans, sha, ny, participate, false,
# Nearest to test: fierce, crusade, favorably, way, inte, carmel, recently, conscious,
# Nearest to scale: lugo, marty, page, prohibits, tristram, dieter, domain, seem,
# Nearest to cost: booming, entrepreneurship, prominently, presley, captains, aurelia, sites, named,
# Nearest to know: hoped, nymphet, leaders, drive, popping, digestion, acct, bechtel,
# Nearest to defense: xenophobic, imperial, litigation, diary, cryptanalysis, recommend, capabilities, mepkin,
# Nearest to primarily: acknowledged, pumped, summits, dominion, akad, individual, linguists, roos,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9308 0.2495 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8862 0.2468 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8622 0.2471 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8668 0.2452 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8199 0.2373 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8173 0.2122 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8042 0.2116 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7920 0.2120 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7836 0.2117 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7526 0.2123 sec/batch
# Nearest to up: villa, illusion, competing, decrease, computation, mexico, modifications, transport,
# Nearest to is: ride, deductive, qm, later, extant, exposure, chair, toys,
# Nearest to that: screaming, maketh, embracing, parliamentarian, originals, dharma, laziness, replaced,
# Nearest to most: ncos, resorts, balder, deville, superb, grammys, rhyming, plain,
# Nearest to often: potential, presupposes, scribe, manuscript, crossing, sincerity, diets, strive,
# Nearest to so: limited, manners, historic, focusing, buttons, nicholas, adherent, hospital,
# Nearest to called: lonely, wrapped, importance, inception, chapterhouse, leaf, ambitions, godhead,
# Nearest to also: attractive, deltas, correlation, wikipedia, differentiating, malthus, promote, armagh,
# Nearest to operating: conquer, multiplexing, daylight, dutch, dealt, kite, untold, doughnut,
# Nearest to assembly: terrorists, centrale, sha, scans, willard, specter, satisfy, lagi,
# Nearest to test: fierce, crusade, favorably, conscious, way, mortality, carmel, pogroms,
# Nearest to scale: lugo, page, prohibits, marty, tristram, domain, macedonian, sobriquet,
# Nearest to cost: booming, entrepreneurship, captains, presley, prominently, aurelia, oral, dislike,
# Nearest to know: hoped, nymphet, drive, leaders, digestion, popping, fast, spoiled,
# Nearest to defense: xenophobic, imperial, litigation, diary, capabilities, recommend, hospitals, cryptanalysis,
# Nearest to primarily: acknowledged, summits, pumped, linguists, dominion, notional, rate, akad,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7705 0.2143 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7519 0.2123 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7349 0.2123 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7128 0.2120 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7573 0.2132 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7262 0.2130 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7279 0.2123 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7324 0.2121 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7016 0.2206 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6776 0.2335 sec/batch
# Nearest to up: villa, illusion, competing, computation, decrease, this, sidi, lingvo,
# Nearest to is: qm, deductive, toys, ride, extant, exposure, used, capital,
# Nearest to that: maketh, embracing, originals, screaming, fad, you, parliamentarian, dharma,
# Nearest to most: resorts, deville, grammys, balder, superb, rhyming, genomes, ncos,
# Nearest to often: potential, presupposes, scribe, sincerity, crossing, traditional, immersion, chosenness,
# Nearest to so: limited, unproved, buttons, focusing, sheltering, lubbock, graf, nicholas,
# Nearest to called: lonely, wrapped, godhead, leaf, absurd, chapterhouse, importance, provably,
# Nearest to also: deltas, attractive, wikipedia, malthus, demographically, correlation, approached, attributable,
# Nearest to operating: multiplexing, daylight, conquer, menteith, optimal, smarter, untold, dealt,
# Nearest to assembly: terrorists, centrale, lagi, willard, specter, sha, participate, scans,
# Nearest to test: fierce, inte, favorably, crusade, pogroms, conscious, carmel, kendrick,
# Nearest to scale: lugo, page, tristram, prohibits, marty, tissues, domain, macedonian,
# Nearest to cost: booming, presley, circassians, oral, coastlines, captains, entrepreneurship, prominently,
# Nearest to know: spoiled, hoped, drive, fast, popping, elle, nymphet, markschies,
# Nearest to defense: xenophobic, litigation, imperial, troposphere, sockets, sleepless, deianira, perth,
# Nearest to primarily: summits, acknowledged, pumped, roos, notional, linguists, dominion, inflexible,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6930 0.2159 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6556 0.2156 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6253 0.2180 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6332 0.2294 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6361 0.2275 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6071 0.2486 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6030 0.1826 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5621 0.2481 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5331 0.2500 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4899 0.2498 sec/batch
# Nearest to up: illusion, villa, competing, computation, this, decrease, mackinac, epigram,
# Nearest to is: qm, deductive, used, exposure, boolean, toys, capital, chair,
# Nearest to that: originals, maketh, screaming, you, embracing, dharma, laziness, fad,
# Nearest to most: deville, resorts, grammys, balder, caucasian, vessel, genomes, resistive,
# Nearest to often: potential, scribe, presupposes, traditional, crossing, sincerity, replicated, chosenness,
# Nearest to so: limited, unproved, sheltering, lubbock, ethnomusicology, focusing, disorderly, buttons,
# Nearest to called: lonely, leaf, lookup, godhead, kullervo, such, absurd, provably,
# Nearest to also: deltas, electrochemistry, attractive, demographically, wikipedia, correlation, fathoms, promote,
# Nearest to operating: multiplexing, menteith, daylight, improves, space, smarter, shown, optimal,
# Nearest to assembly: lagi, terrorists, centrale, judicial, representatives, prime, sha, willard,
# Nearest to test: fierce, inte, conscious, carmel, kendrick, wrongfully, crusade, frankenheimer,
# Nearest to scale: tissues, tristram, page, lugo, prohibits, marty, domain, beige,
# Nearest to cost: booming, circassians, oral, coastlines, presley, copland, prominently, dniester,
# Nearest to know: elle, spoiled, hoped, nymphet, fast, digestion, galante, bechtel,
# Nearest to defense: xenophobic, imperial, troposphere, sockets, litigation, karami, sleepless, classicist,
# Nearest to primarily: summits, acknowledged, roos, pumped, inflexible, linguists, notional, cardiovascular,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4919 0.2500 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4751 0.2489 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4608 0.2486 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5242 0.2485 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4973 0.2484 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4620 0.2491 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4620 0.2508 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4228 0.2488 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4258 0.2497 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4246 0.2488 sec/batch
# Nearest to up: illusion, villa, decrease, mackinac, competing, this, computation, lingvo,
# Nearest to is: used, qm, deductive, exposure, boolean, table, lazare, chair,
# Nearest to that: you, originals, embracing, maketh, screaming, all, fad, laziness,
# Nearest to most: deville, resorts, grammys, caucasian, resistive, landfills, balder, vessel,
# Nearest to often: potential, presupposes, scribe, traditional, chosenness, sincerity, crossing, strive,
# Nearest to so: unproved, limited, sheltering, disorderly, lubbock, triadic, usbc, psc,
# Nearest to called: leaf, lookup, godhead, absurd, lonely, provably, kullervo, such,
# Nearest to also: deltas, demographically, electrochemistry, haliaeetus, mou, deals, malthus, fathoms,
# Nearest to operating: interface, multiplexing, menteith, graphical, daylight, smarter, space, basic,
# Nearest to assembly: judicial, prime, representatives, parties, lagi, terrorists, dictatorship, centrale,
# Nearest to test: fierce, inte, conscious, kendrick, carmel, frankenheimer, thoroughbreds, dnb,
# Nearest to scale: tissues, tristram, page, domain, prohibits, lugo, marty, beige,
# Nearest to cost: booming, circassians, oral, coastlines, copland, electrical, sites, dniester,
# Nearest to know: elle, spoiled, fast, hoped, nymphet, activation, digestion, bechtel,
# Nearest to defense: xenophobic, imperial, troposphere, sockets, sleepless, karami, litigation, hospitals,
# Nearest to primarily: summits, acknowledged, roos, pumped, linguists, inflexible, cardiovascular, notional,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4472 0.2506 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3882 0.2484 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4192 0.2483 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4029 0.2489 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4121 0.2467 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4646 0.2541 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3973 0.2543 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3603 0.2559 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4144 0.2448 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3862 0.2417 sec/batch
# Nearest to up: illusion, decrease, villa, logarithm, mackinac, lingvo, this, coursing,
# Nearest to is: qm, used, exposure, deductive, boolean, illustrated, lazare, suffices,
# Nearest to that: you, originals, embracing, fad, spouse, all, racism, maketh,
# Nearest to most: deville, grammys, landfills, caucasian, resorts, resistive, vessel, balder,
# Nearest to often: potential, scribe, chosenness, presupposes, strive, traditional, crossing, inclined,
# Nearest to so: unproved, disorderly, vld, usbc, lubbock, limited, sheltering, triadic,
# Nearest to called: leaf, godhead, lookup, absurd, lonely, provably, contingencies, kullervo,
# Nearest to also: deltas, electrochemistry, demographically, haliaeetus, wikipedia, mou, correlation, zealous,
# Nearest to operating: interface, multiplexing, graphical, menteith, daylight, browser, smarter, pyroxene,
# Nearest to assembly: judicial, parties, representatives, prime, lagi, dictatorship, terrorists, suffrage,
# Nearest to test: inte, fierce, conscious, thoroughbreds, kendrick, indexes, void, challenged,
# Nearest to scale: tissues, tristram, page, beige, domain, lugo, prohibits, protoscience,
# Nearest to cost: booming, electrical, coastlines, copland, circassians, luft, oral, ibm,
# Nearest to know: elle, articulated, spoiled, hoped, fast, universals, activation, bechtel,
# Nearest to defense: xenophobic, troposphere, sockets, imperial, hegemonic, sleepless, karami, litigation,
# Nearest to primarily: summits, inflexible, roos, acknowledged, linguists, notional, nomadic, cardiovascular,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3817 0.2434 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4136 0.2458 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3639 0.2335 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3476 0.2353 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3789 0.2349 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3454 0.2496 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3865 0.2235 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3875 0.2211 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3070 0.2392 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3338 0.2732 sec/batch
# Nearest to up: illusion, logarithm, villa, coursing, decrease, mackinac, sidi, sending,
# Nearest to is: used, qm, deductive, exposure, lazare, boolean, unethical, convenient,
# Nearest to that: you, racism, embracing, incomparable, imparting, hisham, depart, all,
# Nearest to most: grammys, resorts, deville, landfills, caucasian, vessel, superb, balder,
# Nearest to often: traditional, scribe, presupposes, potential, chosenness, strive, condemn, inclined,
# Nearest to so: unproved, disorderly, instead, lubbock, usbc, limited, vld, sheltering,
# Nearest to called: leaf, lookup, godhead, absurd, kullervo, lonely, contingencies, provably,
# Nearest to also: demographically, deltas, haliaeetus, electrochemistry, correlation, wikipedia, mou, attractive,
# Nearest to operating: interface, graphical, multiplexing, browser, hardware, daylight, menteith, user,
# Nearest to assembly: judicial, representatives, prime, parties, suffrage, lagi, dictatorship, terrorists,
# Nearest to test: inte, fierce, thoroughbreds, indexes, tilings, conscious, dnb, sufferers,
# Nearest to scale: tissues, tristram, beige, page, gramophone, protoscience, lugo, domain,
# Nearest to cost: booming, luft, copland, coastlines, electrical, circassians, captains, ibm,
# Nearest to know: elle, articulated, spoiled, markschies, universals, hoped, fast, bechtel,
# Nearest to defense: xenophobic, troposphere, sockets, hegemonic, perth, unnavigable, imperial, sleepless,
# Nearest to primarily: summits, inflexible, nomadic, linguists, acknowledged, roos, outgrowth, notional,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3605 0.2640 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2941 0.2580 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3879 0.2577 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3379 0.2585 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3855 0.2538 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2817 0.2351 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2874 0.2362 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3282 0.2262 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2327 0.2427 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3320 0.2394 sec/batch
# Nearest to up: illusion, villa, coursing, door, daydream, mackinac, sending, competing,
# Nearest to is: qm, deductive, used, lazare, boolean, generalized, convenient, dde,
# Nearest to that: you, laziness, statement, indeed, imparting, perverted, depart, fad,
# Nearest to most: grammys, resorts, landfills, deville, superb, caucasian, resistive, balder,
# Nearest to often: traditional, presupposes, potential, scribe, chosenness, strive, inclined, condemn,
# Nearest to so: unproved, disorderly, instead, usbc, vld, statement, triadic, sheltering,
# Nearest to called: leaf, godhead, absurd, lookup, kullervo, sudeten, provably, windmills,
# Nearest to also: demographically, deltas, haliaeetus, mou, electrochemistry, wikipedia, thule, fathoms,
# Nearest to operating: graphical, browser, interface, multiplexing, hardware, mac, smarter, daylight,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, lagi, dictatorship, terrorists,
# Nearest to test: inte, thoroughbreds, indexes, tilings, kendrick, fierce, cramped, conscious,
# Nearest to scale: tissues, tristram, gramophone, beige, page, protoscience, lugo, gysin,
# Nearest to cost: copland, booming, luft, circassians, electrical, coastlines, dniester, stimulating,
# Nearest to know: elle, spoiled, markschies, universals, replied, fast, bdtcs, premillennialism,
# Nearest to defense: xenophobic, troposphere, karami, unnavigable, sockets, hegemonic, perth, hospitals,
# Nearest to primarily: summits, inflexible, nomadic, linguists, roos, outgrowth, acknowledged, notional,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3004 0.2419 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3252 0.2390 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3353 0.1226 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2271 0.2765 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2349 0.2852 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2231 0.2747 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1973 0.2842 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2471 0.2881 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2092 0.2608 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1796 0.2633 sec/batch
# Nearest to up: illusion, daydream, villa, going, mackinac, door, sending, coursing,
# Nearest to is: qm, used, deductive, assembl, boolean, claims, factorizations, exposure,
# Nearest to that: you, depart, incomparable, racism, perverted, spouse, imparting, fad,
# Nearest to most: grammys, superb, resorts, deville, landfills, resistive, caucasian, plain,
# Nearest to often: traditional, potential, strive, presupposes, scribe, condemn, chosenness, crossing,
# Nearest to so: unproved, usbc, instead, weren, disorderly, sheltering, vld, limited,
# Nearest to called: leaf, absurd, lookup, godhead, trophic, windmills, contingencies, shortening,
# Nearest to also: mou, haliaeetus, demographically, deltas, electrochemistry, wikipedia, fathoms, attractive,
# Nearest to operating: graphical, browser, interface, multiplexing, hardware, mac, smarter, daylight,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, dictatorship, lagi, terrorists,
# Nearest to test: inte, fierce, cramped, optimally, thoroughbreds, turrets, tilings, indexes,
# Nearest to scale: tissues, gramophone, page, tristram, gysin, protoscience, beige, soma,
# Nearest to cost: copland, luft, booming, dniester, circassians, ibm, markets, prominently,
# Nearest to know: elle, spoiled, markschies, replied, universals, bdtcs, articulated, fast,
# Nearest to defense: karami, unnavigable, xenophobic, sockets, troposphere, hospitals, hegemonic, litigation,
# Nearest to primarily: summits, nomadic, roos, inflexible, aramaic, sufferer, linguists, outgrowth,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2336 0.2557 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2316 0.2323 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2237 0.2232 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1142 0.2317 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1714 0.2146 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1900 0.2228 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1717 0.2215 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2034 0.2301 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1977 0.2190 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1789 0.2271 sec/batch
# Nearest to up: illusion, going, logarithm, daydream, mackinac, villa, door, joe,
# Nearest to is: used, qm, deductive, radians, boolean, claims, exposure, factorizations,
# Nearest to that: depart, you, optimal, to, catastrophism, imparting, incomparable, perverted,
# Nearest to most: grammys, superb, landfills, deville, resistive, caucasian, resorts, genomes,
# Nearest to often: traditional, presupposes, strive, scribe, potential, inclined, condemn, crossing,
# Nearest to so: instead, usbc, sheltering, disorderly, unproved, weren, vld, limited,
# Nearest to called: leaf, godhead, lookup, absurd, provably, subtree, trophic, shortening,
# Nearest to also: haliaeetus, mou, demographically, electrochemistry, attractive, quantitative, deltas, wikipedia,
# Nearest to operating: graphical, interface, browser, multiplexing, hardware, mac, roms, daylight,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, lagi, terrorists, azerbaijani,
# Nearest to test: inte, turrets, thoroughbreds, fierce, indexes, void, optimally, tilings,
# Nearest to scale: gramophone, page, tristram, tissues, protoscience, gysin, beige, soma,
# Nearest to cost: copland, booming, prominently, luft, circassians, rodman, markets, dniester,
# Nearest to know: elle, replied, markschies, spoiled, universals, premillennialism, bdtcs, articulated,
# Nearest to defense: karami, unnavigable, sockets, troposphere, perth, hegemonic, xenophobic, hospitals,
# Nearest to primarily: summits, nomadic, roos, linguists, cardiovascular, inflexible, outgrowth, acknowledged,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1691 0.2396 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2276 0.2450 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1838 0.2293 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1534 0.2493 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1861 0.2285 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1800 0.2191 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2155 0.2538 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1706 0.2344 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1686 0.2283 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2126 0.2286 sec/batch
# Nearest to up: illusion, villa, mexico, logarithm, going, sidi, speeding, daydream,
# Nearest to is: used, qm, cdots, deductive, radians, satisfies, distributivity, elitist,
# Nearest to that: depart, imparting, incomparable, indeed, atomism, you, proponents, catastrophism,
# Nearest to most: grammys, superb, landfills, deville, caucasian, resistive, muse, resorts,
# Nearest to often: traditional, presupposes, scribe, strive, condemn, inclined, chosenness, mundi,
# Nearest to so: instead, disorderly, usbc, weren, vld, prophecy, uneventful, unproved,
# Nearest to called: leaf, godhead, absurd, trophic, subtree, sudeten, shortening, lookup,
# Nearest to also: haliaeetus, mou, electrochemistry, attractive, demographically, promote, quantitative, deltas,
# Nearest to operating: multiplexing, graphical, hardware, interface, dynamic, browser, daylight, saic,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, sha, lagi, centrale,
# Nearest to test: inte, turrets, optimally, fierce, thoroughbreds, tilings, indexes, void,
# Nearest to scale: tissues, tristram, gramophone, page, gysin, flashed, protoscience, soma,
# Nearest to cost: copland, booming, luft, paid, prominently, rodman, dniester, markets,
# Nearest to know: replied, markschies, elle, spoiled, premillennialism, i, articulated, bdtcs,
# Nearest to defense: unnavigable, hegemonic, troposphere, sockets, karami, tarnished, perth, litigation,
# Nearest to primarily: summits, linguists, nomadic, sufferer, outgrowth, inflexible, acknowledged, roos,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2243 0.2229 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1838 0.2507 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1844 0.2286 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1978 0.2555 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1208 0.2289 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1492 0.2194 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1806 0.2269 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1367 0.2288 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1600 0.2222 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2310 0.2258 sec/batch
# Nearest to up: illusion, villa, going, paekche, relinquish, sidi, reduction, door,
# Nearest to is: used, qm, assembl, radians, claims, veto, capital, factorizations,
# Nearest to that: perverted, depart, imparting, incomparable, to, you, nster, inferiority,
# Nearest to most: grammys, superb, caucasian, deville, landfills, resorts, muse, resistive,
# Nearest to often: traditional, presupposes, strive, scribe, condemn, crossing, vocally, inclined,
# Nearest to so: instead, disorderly, weren, prophecy, vld, usbc, uneventful, unmentioned,
# Nearest to called: leaf, absurd, godhead, subtree, trophic, paperwork, sudeten, lookup,
# Nearest to also: mou, haliaeetus, promote, electrochemistry, attractive, demographically, wikipedia, quantitative,
# Nearest to operating: graphical, multiplexing, daylight, dynamic, saic, browser, restored, swadesh,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, lagi, azerbaijani, dictatorship,
# Nearest to test: inte, turrets, optimally, fierce, indexes, tilings, pwned, wetlands,
# Nearest to scale: gramophone, xhosa, tristram, soma, gysin, tissues, theoreticians, page,
# Nearest to cost: copland, paid, booming, rodman, prominently, luft, entrepreneurship, dniester,
# Nearest to know: replied, markschies, elle, spoiled, i, stupid, angkor, premillennialism,
# Nearest to defense: unnavigable, hegemonic, karami, perth, sockets, bay, troposphere, hypnotists,
# Nearest to primarily: summits, nomadic, linguists, outgrowth, sufferer, wuthering, inflexible, roos,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2698 0.2270 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1332 0.2142 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1515 0.2487 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1449 0.2270 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0404 0.2224 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1374 0.2367 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1101 0.2434 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1447 0.2121 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1852 0.0402 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1111 0.2122 sec/batch
# Nearest to up: going, illusion, joe, paekche, door, villa, seceding, relinquish,
# Nearest to is: used, qm, radians, counterbalancing, durio, assembl, convenient, suffices,
# Nearest to that: perverted, depart, imparting, you, incomparable, to, sentencing, catastrophism,
# Nearest to most: grammys, superb, caucasian, resistive, resorts, landfills, deville, newbie,
# Nearest to often: traditional, presupposes, strive, scribe, condemn, inclined, crossing, liberating,
# Nearest to so: instead, disorderly, vld, usbc, unmentioned, weren, uneventful, wait,
# Nearest to called: leaf, lookup, equivalents, paperwork, which, brahmagupta, godhead, trophic,
# Nearest to also: haliaeetus, mou, electrochemistry, attractive, promote, quantitative, demographically, fathoms,
# Nearest to operating: graphical, mac, enhancements, hardware, multiplexing, dynamic, browser, saic,
# Nearest to assembly: judicial, representatives, prime, suffrage, parties, azerbaijani, sha, lagi,
# Nearest to test: turrets, inte, pwned, fierce, wetlands, optimally, thoroughbreds, void,
# Nearest to scale: gramophone, diatonic, gysin, page, theoreticians, tissues, unaccompanied, flashed,
# Nearest to cost: copland, paid, markets, rodman, luft, booming, borrowing, reflecting,
# Nearest to know: replied, markschies, elle, spoiled, i, bdtcs, angkor, premillennialism,
# Nearest to defense: unnavigable, karami, tarnished, hegemonic, troposphere, sockets, perth, litigation,
# Nearest to primarily: summits, outgrowth, nomadic, retail, sufferer, wuthering, linguists, religiously,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1012 0.2143 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0515 0.2125 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0970 0.2127 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0597 0.2121 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1162 0.2127 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0143 0.2121 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0823 0.2124 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0996 0.2119 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1119 0.2116 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0476 0.2122 sec/batch
# Nearest to up: joe, illusion, going, relinquish, door, seceding, paekche, villa,
# Nearest to is: used, qm, assembl, radians, claims, or, someone, anthropogenic,
# Nearest to that: depart, to, perverted, imparting, catastrophism, contradicts, incomparable, you,
# Nearest to most: grammys, superb, caucasian, resistive, hamadan, muse, landfills, deville,
# Nearest to often: traditional, presupposes, strive, crossing, scribe, condemn, modi, inclined,
# Nearest to so: vld, disorderly, instead, uneventful, weren, wait, unmentioned, usbc,
# Nearest to called: leaf, subtree, lookup, godhead, shortening, paperwork, which, brahmagupta,
# Nearest to also: haliaeetus, mou, electrochemistry, promote, attractive, demographically, quantitative, thule,
# Nearest to operating: graphical, mac, swadesh, multiplexing, hardware, interface, enhancements, dynamic,
# Nearest to assembly: judicial, representatives, prime, sha, azerbaijani, centrale, suffrage, zoroastrians,
# Nearest to test: turrets, fierce, inte, wetlands, pwned, challenged, thoroughbreds, cricket,
# Nearest to scale: gramophone, tissues, soma, theoreticians, flashed, diatonic, unaccompanied, gysin,
# Nearest to cost: copland, paid, rodman, entrepreneurship, luft, prominently, booming, reflecting,
# Nearest to know: replied, markschies, elle, spoiled, i, say, me, coincidences,
# Nearest to defense: unnavigable, karami, troposphere, tarnished, hegemonic, sockets, pill, perth,
# Nearest to primarily: summits, outgrowth, nomadic, linguists, wuthering, sufferer, aramaic, retail,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0242 0.2136 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0151 0.2123 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0139 0.2112 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0644 0.2117 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0918 0.2119 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0553 0.2121 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0534 0.2120 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1054 0.2115 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0633 0.2121 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0420 0.2117 sec/batch
# Nearest to up: illusion, going, relinquish, door, joe, paekche, seceding, logarithm,
# Nearest to is: used, radians, of, to, a, someone, qm, or,
# Nearest to that: to, depart, imparting, catastrophism, perverted, incomparable, indeed, all,
# Nearest to most: grammys, superb, resistive, hamadan, muse, caucasian, deville, landfills,
# Nearest to often: traditional, presupposes, strive, condemn, inclined, aberration, vocally, crossing,
# Nearest to so: instead, disorderly, vld, uneventful, statement, usbc, wait, weren,
# Nearest to called: leaf, subtree, which, lookup, brahmagupta, shortening, godhead, contingencies,
# Nearest to also: mou, haliaeetus, electrochemistry, attractive, promote, quantitative, and, brief,
# Nearest to operating: multiplexing, daylight, graphical, mac, kite, swadesh, hardware, enhancements,
# Nearest to assembly: judicial, representatives, prime, sha, suffrage, centrale, azerbaijani, zoroastrians,
# Nearest to test: turrets, wetlands, fierce, challenged, thoroughbreds, inte, optimally, cricket,
# Nearest to scale: tissues, gramophone, soma, flashed, unaccompanied, protoscience, theoreticians, xhosa,
# Nearest to cost: rodman, paid, copland, entrepreneurship, luft, examines, reflecting, prominently,
# Nearest to know: replied, markschies, elle, i, spoiled, say, articulated, me,
# Nearest to defense: unnavigable, karami, hegemonic, tarnished, troposphere, arrests, hypnotists, perth,
# Nearest to primarily: summits, outgrowth, nomadic, wuthering, sufferer, religiously, relatively, aramaic,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0680 0.2143 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0725 0.2337 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0685 0.2492 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0521 0.2188 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0859 0.2164 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0446 0.2311 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0743 0.2178 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0687 0.2139 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0679 0.2185 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0611 0.2257 sec/batch
# Nearest to up: seceding, relinquish, paekche, illusion, mexico, edict, reduction, door,
# Nearest to is: used, qm, radians, suffices, someone, assembl, to, be,
# Nearest to that: to, depart, imparting, perverted, catastrophism, contradicts, incomparable, criticise,
# Nearest to most: grammys, superb, hamadan, caucasian, resistive, muse, deville, specially,
# Nearest to often: traditional, presupposes, strive, condemn, inclined, modi, scribe, vocally,
# Nearest to so: disorderly, vld, uneventful, statement, wait, deira, instead, usbc,
# Nearest to called: leaf, subtree, godhead, which, brahmagupta, shortening, paperwork, absurd,
# Nearest to also: mou, haliaeetus, attractive, promote, electrochemistry, quantitative, brief, syncretic,
# Nearest to operating: graphical, mac, enhancements, interface, multiplexing, browser, swadesh, daylight,
# Nearest to assembly: judicial, representatives, prime, centrale, sha, azerbaijani, suffrage, zoroastrians,
# Nearest to test: turrets, challenged, wetlands, fierce, optimally, cricket, inte, thoroughbreds,
# Nearest to scale: gramophone, unaccompanied, xhosa, tissues, theoreticians, flashed, soma, protoscience,
# Nearest to cost: entrepreneurship, rodman, copland, paid, borrowing, luft, examines, evaluate,
# Nearest to know: markschies, replied, i, elle, say, articulated, spoiled, me,
# Nearest to defense: unnavigable, troposphere, hegemonic, karami, tarnished, bay, arrests, hypnotists,
# Nearest to primarily: summits, outgrowth, nomadic, wuthering, sufferer, relatively, aramaic, notional,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0439 0.2343 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9925 0.2148 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0347 0.2141 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0648 0.2148 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0792 0.2152 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1230 0.2146 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1230 0.2140 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0431 0.2146 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0372 0.2137 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0709 0.2132 sec/batch
# Nearest to up: seceding, relinquish, door, paekche, illusion, coursing, going, joe,
# Nearest to is: used, radians, qm, be, deductive, or, suffices, to,
# Nearest to that: to, imparting, depart, perverted, contradicts, catastrophism, indeed, statement,
# Nearest to most: grammys, superb, hamadan, caucasian, specially, urdu, newbie, muse,
# Nearest to often: traditional, presupposes, strive, condemn, inclined, vocally, modi, scribe,
# Nearest to so: disorderly, vld, uneventful, instead, deira, wait, oo, buttons,
# Nearest to called: leaf, subtree, which, brahmagupta, shortening, paperwork, godhead, equivalents,
# Nearest to also: haliaeetus, mou, attractive, electrochemistry, and, promote, quantitative, adoption,
# Nearest to operating: graphical, mac, dynamic, multiplexing, browser, daylight, interface, swadesh,
# Nearest to assembly: judicial, prime, representatives, zoroastrians, centrale, azerbaijani, suffrage, sha,
# Nearest to test: turrets, wetlands, challenged, cricket, inte, fierce, tilings, pwned,
# Nearest to scale: gramophone, unaccompanied, diatonic, theoreticians, flashed, tissues, xhosa, soma,
# Nearest to cost: rodman, paid, entrepreneurship, copland, borrowing, examines, kaifu, luft,
# Nearest to know: replied, markschies, i, elle, me, stupid, say, my,
# Nearest to defense: troposphere, karami, unnavigable, hegemonic, tarnished, arrests, minurso, hypnotists,
# Nearest to primarily: summits, outgrowth, wuthering, nomadic, relatively, aramaic, sufferer, niche,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9945 0.2161 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0269 0.2144 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0379 0.2166 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0261 0.2278 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0693 0.2229 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0325 0.1956 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0171 0.2122 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9859 0.2127 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0178 0.2122 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9575 0.2120 sec/batch
# Nearest to up: seceding, relinquish, joe, going, illusion, paekche, advancing, door,
# Nearest to is: someone, qm, radians, claims, used, of, be, deductive,
# Nearest to that: to, imparting, perverted, depart, indeed, it, all, catastrophism,
# Nearest to most: grammys, superb, hamadan, specially, caucasian, muse, fuerteventura, urdu,
# Nearest to often: traditional, presupposes, strive, condemn, modi, musicianship, inclined, aberration,
# Nearest to so: disorderly, vld, usbc, uneventful, deira, wait, prophecy, adherent,
# Nearest to called: leaf, brahmagupta, which, subtree, godhead, shortening, paperwork, mutations,
# Nearest to also: mou, haliaeetus, electrochemistry, attractive, promote, brief, and, huangdi,
# Nearest to operating: graphical, mac, multiplexing, daylight, dynamic, hardware, enhancements, browser,
# Nearest to assembly: judicial, prime, representatives, centrale, zoroastrians, sha, serialisation, lagi,
# Nearest to test: turrets, cricket, wetlands, fierce, challenged, thoroughbreds, pwned, tilings,
# Nearest to scale: diatonic, gramophone, unaccompanied, flashed, tissues, theoreticians, bending, soma,
# Nearest to cost: copland, paid, rodman, entrepreneurship, examines, borrowing, samsung, kaifu,
# Nearest to know: replied, markschies, i, me, elle, spoiled, articulated, stupid,
# Nearest to defense: troposphere, karami, hegemonic, unnavigable, tarnished, minurso, arrests, thwart,
# Nearest to primarily: wuthering, outgrowth, summits, nomadic, niche, sufferer, discontinued, aramaic,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9978 0.2145 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9368 0.2123 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0038 0.2121 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0287 0.2121 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0283 0.2121 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0022 0.2123 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9087 0.2127 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9904 0.2114 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9332 0.2146 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9744 0.2378 sec/batch
# Nearest to up: joe, seceding, illusion, reduction, relinquish, going, advancing, coursing,
# Nearest to is: to, of, a, used, the, be, or, someone,
# Nearest to that: to, it, imparting, all, depart, indeed, perverted, catastrophism,
# Nearest to most: grammys, hamadan, superb, specially, approximately, caucasian, resistive, muse,
# Nearest to often: traditional, presupposes, strive, condemn, modi, examples, inclined, musicianship,
# Nearest to so: vld, disorderly, uneventful, instead, adherent, usbc, deira, wait,
# Nearest to called: leaf, subtree, which, brahmagupta, shortening, godhead, is, the,
# Nearest to also: haliaeetus, electrochemistry, mou, attractive, and, the, quantitative, promote,
# Nearest to operating: graphical, multiplexing, mac, daylight, kite, swadesh, enhancements, distro,
# Nearest to assembly: judicial, prime, representatives, centrale, zoroastrians, parliament, serialisation, suffrage,
# Nearest to test: wetlands, turrets, cricket, challenged, fierce, thoroughbreds, pwned, tilings,
# Nearest to scale: unaccompanied, gramophone, diatonic, tissues, flashed, deacidification, bending, theoreticians,
# Nearest to cost: rodman, paid, entrepreneurship, copland, borrowing, kaifu, prominently, examines,
# Nearest to know: replied, markschies, i, elle, me, spoiled, articulated, say,
# Nearest to defense: troposphere, karami, unnavigable, hegemonic, tarnished, bay, minurso, arrests,
# Nearest to primarily: niche, outgrowth, summits, wuthering, zx, inefficiencies, discontinued, sufferer,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0076 0.2167 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0326 0.2150 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9540 0.2143 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0257 0.2146 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0215 0.2153 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9425 0.2141 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0045 0.2331 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0088 0.2192 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0155 0.2242 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0090 0.2204 sec/batch
# Nearest to up: seceding, relinquish, joe, advancing, illusion, reduction, paekche, going,
# Nearest to is: to, a, of, decide, someone, used, in, assembl,
# Nearest to that: to, imparting, depart, indeed, catastrophism, perverted, it, all,
# Nearest to most: hamadan, superb, grammys, specially, muse, deville, caucasian, yaobang,
# Nearest to often: presupposes, traditional, strive, condemn, vocally, examples, musicianship, aberration,
# Nearest to so: vld, disorderly, statement, usbc, oo, uneventful, prophecy, adherent,
# Nearest to called: leaf, subtree, which, godhead, brahmagupta, shortening, a, paperwork,
# Nearest to also: haliaeetus, mou, and, electrochemistry, promote, attractive, brief, the,
# Nearest to operating: graphical, multiplexing, daylight, swadesh, mac, dynamic, distro, mightiest,
# Nearest to assembly: judicial, prime, representatives, centrale, zoroastrians, sha, serialisation, azerbaijani,
# Nearest to test: wetlands, turrets, cricket, challenged, fierce, layer, optimally, tilings,
# Nearest to scale: unaccompanied, gramophone, diatonic, tissues, flashed, deacidification, theoreticians, decade,
# Nearest to cost: entrepreneurship, rodman, paid, borrowing, copland, examines, reflecting, kaifu,
# Nearest to know: replied, markschies, i, me, spoiled, t, articulated, elle,
# Nearest to defense: troposphere, karami, unnavigable, hegemonic, tarnished, bay, hypnotists, minurso,
# Nearest to primarily: wuthering, niche, inefficiencies, outgrowth, later, zx, sufferer, summits,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0039 0.2481 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9960 0.2293 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9813 0.2228 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0001 0.2398 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0223 0.2480 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0139 0.2249 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9651 0.2393 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9499 0.2439 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9702 0.2417 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0236 0.2360 sec/batch
# Nearest to up: seceding, reduction, together, paekche, advancing, relinquish, shiv, edict,
# Nearest to is: to, a, of, the, or, decide, be, used,
# Nearest to that: to, depart, imparting, it, perverted, all, hisham, embracing,
# Nearest to most: superb, hamadan, grammys, caucasian, specially, muse, regularly, urdu,
# Nearest to often: presupposes, traditional, strive, condemn, vocally, modi, aberration, examples,
# Nearest to so: vld, disorderly, oo, adherent, usbc, wait, uneventful, instead,
# Nearest to called: leaf, which, subtree, a, shortening, the, brahmagupta, paperwork,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8253 0.2774 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8656 0.2777 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8927 0.2775 sec/batch
# Nearest to up: together, advancing, cube, haddock, seceding, sensual, worlds, joe,
# Nearest to is: a, of, the, in, as, to, also, this,
# Nearest to that: to, it, the, but, not, in, would, as,
# Nearest to most: including, other, were, in, and, was, superb, hamadan,
# Nearest to often: examples, frequent, usually, condemn, used, jingles, commonly, aberration,
# Nearest to so: oo, chosen, adherent, pence, montenegro, our, kyat, mekugi,
# Nearest to called: the, which, to, a, as, is, and, leaf,
# Nearest to also: the, and, of, in, as, is, a, for,
# Nearest to operating: graphical, roundheads, dynamic, directly, labial, valvular, imitate, angiography,
# Nearest to assembly: judicial, serialisation, zoroastrians, kamchatsky, assoumani, benin, prime, quotations,
# Nearest to test: tests, wetlands, cricket, wastes, turrets, ban, signed, hazardous,
# Nearest to scale: scales, diatonic, infty, bending, theoreticians, page, decade, lcs,
# Nearest to cost: examines, courts, rodman, useless, entrepreneurship, cheapest, film, costs,
# Nearest to know: replied, we, i, markschies, t, my, wouldn, me,
# Nearest to defense: narrator, discuss, masculist, letterboxed, tackle, unnavigable, sockets, hypnotists,
# Nearest to primarily: zx, inefficiencies, hypnotherapists, later, relatively, niche, outgrowth, esdi,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8429 0.2692 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8353 0.2373 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8524 0.2374 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8586 0.2389 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8750 0.2373 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8850 0.2383 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8608 0.2380 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8374 0.2377 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8996 0.2381 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8646 0.2377 sec/batch
# Nearest to up: together, advancing, seceding, from, sensual, haddock, secretly, reduction,
# Nearest to is: a, of, the, to, as, it, by, also,
# Nearest to that: to, it, the, not, would, as, a, but,
# Nearest to most: including, other, hamadan, were, superb, used, are, which,
# Nearest to often: examples, usually, frequent, sometimes, used, commonly, condemn, occasionally,
# Nearest to so: pence, chosen, instead, uneventful, adherent, oo, our, kyat,
# Nearest to called: which, the, a, is, to, as, and, leaf,
# Nearest to also: and, the, of, as, is, in, for, a,
# Nearest to operating: labial, graphical, roundheads, tifinagh, dynamic, rooney, imitate, angiography,
# Nearest to assembly: judicial, serialisation, dictatorship, prime, zoroastrians, assoumani, benin, kamchatsky,
# Nearest to test: tests, wetlands, cricket, wastes, ban, turrets, hazardous, weighed,
# Nearest to scale: scales, diatonic, infty, decade, bending, theoreticians, deacidification, instantaneously,
# Nearest to cost: examines, courts, cheapest, useless, rodman, treasury, entrepreneurship, gasolines,
# Nearest to know: replied, we, i, t, markschies, me, wouldn, articulated,
# Nearest to defense: narrator, masculist, discuss, hegemonic, letterboxed, tackle, unnavigable, krajina,
# Nearest to primarily: zx, inefficiencies, relatively, hypnotherapists, outgrowth, later, accepted, lubavitch,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8720 0.2407 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8554 0.2383 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8310 0.2380 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8415 0.2508 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8967 0.2386 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8770 0.2389 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9655 0.2385 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8734 0.2373 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9337 0.2380 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8133 0.2378 sec/batch
# Nearest to up: together, seceding, sensual, advancing, nearby, crediting, secretly, scary,
# Nearest to is: a, the, of, as, it, also, or, to,
# Nearest to that: to, the, not, it, would, but, as, in,
# Nearest to most: including, hamadan, other, and, were, superb, in, of,
# Nearest to often: examples, usually, frequent, commonly, appetites, used, sometimes, occasionally,
# Nearest to so: pence, oo, kyat, uneventful, chosen, give, coloured, dialects,
# Nearest to called: a, is, which, the, as, to, leaf, such,
# Nearest to also: and, the, of, is, as, in, a, for,
# Nearest to operating: tifinagh, labial, roundheads, rooney, hindu, graphical, angiography, imitate,
# Nearest to assembly: serialisation, judicial, zoroastrians, dictatorship, assoumani, quotations, naturalizing, kamchatsky,
# Nearest to test: tests, wetlands, signed, wastes, cricket, ban, turrets, hazardous,
# Nearest to scale: scales, diatonic, theoreticians, decade, bending, infty, lubavitch, instantaneously,
# Nearest to cost: examines, courts, cheapest, useless, rodman, entrepreneurship, treasury, borrowing,
# Nearest to know: replied, i, t, we, markschies, me, my, wouldn,
# Nearest to defense: narrator, discuss, masculist, letterboxed, defence, hegemonic, capabilities, maga,
# Nearest to primarily: zx, inefficiencies, relatively, outgrowth, accepted, lubavitch, more, hypnotherapists,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7863 0.2393 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8388 0.2379 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7946 0.2379 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9064 0.2382 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8378 0.2376 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8247 0.2380 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9108 0.1444 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8223 0.2419 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8566 0.2412 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8144 0.2428 sec/batch
# Nearest to up: together, seceding, advancing, secretly, nearby, sensual, cube, from,
# Nearest to is: a, of, in, the, also, as, by, it,
# Nearest to that: to, not, it, the, but, would, in, be,
# Nearest to most: hamadan, including, other, superb, were, was, in, used,
# Nearest to often: examples, usually, frequent, condemn, commonly, used, most, appetites,
# Nearest to so: chosen, uneventful, kyat, give, adherent, deira, our, oo,
# Nearest to called: a, which, is, the, to, as, in, known,
# Nearest to also: the, and, of, is, in, as, a, for,
# Nearest to operating: graphical, roundheads, labial, tifinagh, angiography, rooney, imitate, danios,
# Nearest to assembly: judicial, serialisation, zoroastrians, dictatorship, kamchatsky, quotations, benin, assoumani,
# Nearest to test: tests, wetlands, cricket, wastes, ban, turrets, signed, hazardous,
# Nearest to scale: scales, diatonic, decade, infty, lubavitch, theoreticians, bending, instantaneously,
# Nearest to cost: examines, courts, cheapest, entrepreneurship, borrowing, treasury, copland, paid,
# Nearest to know: replied, we, i, t, markschies, me, articulated, my,
# Nearest to defense: narrator, discuss, tackle, masculist, letterboxed, sockets, intramural, capabilities,
# Nearest to primarily: zx, inefficiencies, relatively, hypnotherapists, esdi, lubavitch, outgrowth, accepted,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8225 0.2487 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8620 0.2603 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8390 0.2587 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8093 0.2412 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8551 0.2375 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8372 0.2372 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8923 0.2380 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7485 0.2394 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8487 0.2757 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7804 0.2602 sec/batch
# Nearest to up: together, cube, advancing, sensual, cac, would, from, crediting,
# Nearest to is: a, of, the, also, in, as, it, are,
# Nearest to that: to, the, it, not, in, all, there, but,
# Nearest to most: hamadan, other, including, in, of, and, was, used,
# Nearest to often: frequent, examples, condemn, extremely, occasionally, usually, icons, jingles,
# Nearest to so: chosen, adherent, uneventful, oo, pence, give, kyat, quartz,
# Nearest to called: a, the, is, which, as, to, such, in,
# Nearest to also: the, of, and, is, in, as, a, for,
# Nearest to operating: roundheads, graphical, labial, rooney, tifinagh, angiography, danios, heliport,
# Nearest to assembly: judicial, serialisation, zoroastrians, assoumani, dictatorship, elected, quotations, benin,
# Nearest to test: tests, wetlands, cricket, wastes, signed, turrets, ban, weighed,
# Nearest to scale: scales, diatonic, decade, instantaneously, infty, theoreticians, lubavitch, bending,
# Nearest to cost: examines, courts, cheapest, paid, entrepreneurship, useless, rodman, flagellates,
# Nearest to know: replied, we, i, markschies, t, me, my, articulated,
# Nearest to defense: narrator, discuss, sockets, letterboxed, hegemonic, masculist, tackle, capabilities,
# Nearest to primarily: zx, hypnotherapists, inefficiencies, outgrowth, relatively, lubavitch, esdi, accepted,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7684 0.2463 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8257 0.2629 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8528 0.2496 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8268 0.2598 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7880 0.2659 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8932 0.2440 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8180 0.2651 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8271 0.2463 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8368 0.2714 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8753 0.2445 sec/batch
# Nearest to up: together, cube, advancing, worlds, from, can, this, be,
# Nearest to is: a, the, of, in, as, an, it, or,
# Nearest to that: to, it, not, the, all, there, as, in,
# Nearest to most: other, including, were, hamadan, used, was, and, are,
# Nearest to often: examples, frequent, condemn, usually, most, sometimes, used, extremely,
# Nearest to so: oo, chosen, pence, give, adherent, uneventful, gabab, nur,
# Nearest to called: the, is, a, which, to, as, known, such,
# Nearest to also: the, of, and, as, in, is, a, see,
# Nearest to operating: roundheads, labial, rooney, tifinagh, angiography, heliport, valvular, bakassi,
# Nearest to assembly: judicial, serialisation, zoroastrians, dictatorship, kamchatsky, quotations, benin, elected,
# Nearest to test: tests, wetlands, cricket, signed, wastes, ban, reprocessing, turrets,
# Nearest to scale: scales, decade, diatonic, instantaneously, infty, anthracite, theoreticians, lubavitch,
# Nearest to cost: examines, courts, cheapest, paid, flagellates, useless, entrepreneurship, costs,
# Nearest to know: replied, we, t, i, markschies, me, my, articulated,
# Nearest to defense: narrator, discuss, letterboxed, defence, capabilities, sockets, masculist, peete,
# Nearest to primarily: zx, inefficiencies, hypnotherapists, outgrowth, relatively, esdi, lubavitch, accepted,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8793 0.2502 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8295 0.2879 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8397 0.2446 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8487 0.2407 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8748 0.2756 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8683 0.2534 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8223 0.2636 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8197 0.2741 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7961 0.2762 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8120 0.2795 sec/batch
# Nearest to up: together, from, cube, be, advancing, worlds, reduction, would,
# Nearest to is: a, the, as, of, also, are, it, in,
# Nearest to that: to, it, the, not, there, be, but, in,
# Nearest to most: other, including, were, used, in, hamadan, are, and,
# Nearest to often: examples, frequent, usually, sometimes, most, used, commonly, condemn,
# Nearest to so: oo, chosen, same, pence, uneventful, adherent, give, subjunctive,
# Nearest to called: which, the, a, is, to, as, such, an,
# Nearest to also: and, of, the, is, in, as, a, for,
# Nearest to operating: roundheads, labial, graphical, tifinagh, rooney, heliport, axillary, space,
# Nearest to assembly: judicial, serialisation, zoroastrians, dictatorship, kamchatsky, shave, assoumani, quotations,
# Nearest to test: tests, wetlands, wastes, cricket, signed, ban, reprocessing, turrets,
# Nearest to scale: scales, decade, diatonic, instantaneously, theoreticians, infty, anthracite, bending,
# Nearest to cost: examines, courts, cheapest, paid, flagellates, treasury, borrowing, entrepreneurship,
# Nearest to know: replied, we, markschies, i, t, me, my, wouldn,
# Nearest to defense: narrator, discuss, capabilities, defence, letterboxed, sockets, krajina, masculist,
# Nearest to primarily: zx, inefficiencies, relatively, outgrowth, hypnotherapists, lubavitch, accepted, more,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8501 0.2782 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8111 0.2772 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9368 0.2692 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9146 0.2614 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8887 0.2455 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8247 0.2717 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7977 0.2612 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8387 0.2636 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7185 0.2910 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8724 0.3149 sec/batch
# Nearest to up: together, from, cube, worlds, nearby, crediting, yogas, cac,
# Nearest to is: a, also, of, in, the, are, it, or,
# Nearest to that: it, not, to, the, be, there, but, would,
# Nearest to most: including, other, and, used, of, in, were, are,
# Nearest to often: examples, frequent, sometimes, most, occasionally, usually, appetites, commonly,
# Nearest to so: chosen, give, oo, uneventful, pence, our, same, quartz,
# Nearest to called: which, a, is, the, as, such, from, and,
# Nearest to also: and, of, the, is, in, as, a, see,
# Nearest to operating: angiography, labial, axillary, roundheads, tifinagh, dynamic, graphical, andrew,
# Nearest to assembly: judicial, serialisation, zoroastrians, elected, representatives, kamchatsky, assoumani, dictatorship,
# Nearest to test: tests, wetlands, signed, cricket, wastes, reprocessing, turrets, ban,
# Nearest to scale: scales, diatonic, instantaneously, decade, theoreticians, lubavitch, infty, bending,
# Nearest to cost: examines, cheapest, paid, courts, costs, flagellates, treasury, useless,
# Nearest to know: replied, we, i, markschies, t, me, wouldn, my,
# Nearest to defense: narrator, discuss, defence, capabilities, maga, krajina, affairs, masculist,
# Nearest to primarily: inefficiencies, zx, relatively, hypnotherapists, lubavitch, outgrowth, accepted, amur,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8177 0.2994 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8464 0.2620 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
